# %% [markdown]
# --- **Progetto IAS** ---
#
# Riconoscimento audio DeepFake testando il modello shallow SVM estraendo gli spettrogrammi MEL
#
# * Marco Caruso (60/79/00107)
# * Mauro Contu (60/79/00115)
# * Marco Niccolò Loddo (60/79/00097)

# %% [markdown]
# ##Descrizione dell'agente e dell'ambiente

# %% [markdown]
# ###🌍 Ambiente

# %% [markdown]
# L'ambiente in cui l'agente opera è costituito dall’insieme dei segnali audio digitali in inglese. Il dataset in questione (FakeAVCeleb) è bilanciato ed è composto da 200 audio, suddivisi in: 50 audio real maschili, 50 audio fake maschili, 50 audio real femminili e 50 audio fake femminili. Gli audio fake sono stati creati a partire da quelli real.
# Questo dataset è formato da audio in formato .mp3.
#
# Questi file vocali, oltre che variare in termini di parlante (uomo/donna), variano anche in termini di intonazione, durata (da 3 a 15 secondi circa) e qualità dell'audio.
#
# L'ambiente in questione è:
# * ***Parzialmente osservabile***: abbiamo accesso agli audio forniti e alle loro caratteristiche estratte, ma non conosce esattamente la fonte o il contesto reale dell’audio.
# * ***Stocastico***: gli input audio possono variare molto, contenere rumore o artefatti, e il comportamento del modello può non essere sempre deterministico a causa della complessità del segnale e del modello stesso.
# * ***Statico***: ogni audio viene analizzato singolarmente e il sistema non deve interagire con un ambiente in evoluzione nel tempo o che cambia in modo dinamico durante la classificazione.
# * ***Discreto***: in termini di azioni il modello prende una decisione binaria (real vs fake) per ogni singolo input audio.

# %% [markdown]
# ###👤 Agente

# %% [markdown]
# L'agente in questione è un sistema di classificazione automatica strutturato per distinguere tra audio vocali reali e deepfake, ovvero audio sintetici/manipolati presenti nell'ambiente descritto precedentemente. Questa classificazione si basa su caratteristiche acustiche estratte dai segnali. I passi che segue l'agente per effettuare questa classificazione sono:
#
# 1. ***Preprocessing dell'audio***: gli audio mp3 vengono campionati a una frequenza predefinita, si normalizza il volume di ogni audio e si taglia il silenzio lungo la coda dell'audio (ove presente) utilizzando la feature Energy. Effettuiamo quest'ultima operazione perché dallo studio del dataset, è emerso che la maggior parte degli audio fake presenta appunto un silenzio finale, che può influenzare la direzione della classificazione.
#
# 2. ***Estrazione delle feature***: da ogni segnale pre-processato vengono calcolati gli spettrogrammi Mel, con i corrispettivi delta e delta^2 e poi calcoliamo la media e la deviazione standard per ogni set di feature.
#
#  - Delta: cattura la velocità del cambiamento acustico. È utile per riconoscere transizioni nei fonemi.
#  - Delta^2: misura l’accelerazione del cambiamento. Fornisce un'indicazione della curvatura nel segnale vocale.
#
# 3. ***Modello di classificazione***: viene utilizzato un classificatore supervisionato, ovvero l'SVM (Support Vector Machine) con un kernel non lineare RBF, dove si esegue anche un tuning degli iperparametri C (margine di penalizzazione) e gamma (larghezza del kernel).
#
# 4. ***Addestramento e valutazione***: utilizziamo GridSearchCV con 5-fold cross-validation sul training set per trovare la miglior combinazione di iperparametri, per poi testare il modello ottimizzato sul test-set non ancora visto.

# %% [markdown]
# ***Schema riassuntivo***

# %% [markdown]
# ![MEL_schema.png](data:image/png;base64,...)

# %% [markdown]
# ##Installazione del dataset

# %% [markdown]
# Fase 1: Preparazione e Analisi del Dataset
#
# -Scarichiamo il dataset utilizzando l'ID: 1AKLJoi31Jlk7gJMmqKtnePhdwExD38-c.
#
# Il dataset è suddiviso in cartelle, dove gli audio reali sono nella cartella “Real”, mentre gli audio manipolati sono nella cartella “Fake”.

# %%
from pydrive2.auth import GoogleAuth
from pydrive2.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
downloaded = drive.CreateFile({'id': '1AKLJoi31Jlk7gJMmqKtnePhdwExD38-c'})

# %%
downloaded.GetContentFile('deepfakes_db.zip')

# %%
# !unzip deepfakes_db.zip
# Out:
# Archive:  deepfakes_db.zip
#    creating: FakeAVCeleb_v1.2small/
#    creating: FakeAVCeleb_v1.2small/Fake/
#    creating: FakeAVCeleb_v1.2small/Fake/men/
#    creating: FakeAVCeleb_v1.2small/Fake/men/id00055/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id00055/00120_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id00063/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id00063/00021_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id00171/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id00171/00092_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id00183/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id00183/00015_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id00185/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id00185/00015_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id00186/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id00186/00120_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id00187/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id00187/00360_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id00192/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id00192/00078_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id00225/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id00225/00078_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id00241/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id00241/00015_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id00253/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id00253/00021_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id00265/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id00265/00130_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id00266/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id00266/00470_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id00282/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id00282/00268_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id00292/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id00292/00072_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id00305/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id00305/00113_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id00306/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id00306/00015_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id00358/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id00358/00217_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id00368/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id00368/00078_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id00415/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id00415/00017_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id00498/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id00498/00014_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id00519/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id00519/00028_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id00520/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id00520/00187_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id00535/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id00535/00005_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id00548/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id00548/00015_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id00554/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id00554/00028_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id00559/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id00559/00078_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id00594/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id00594/00005_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id00694/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id00694/00340_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id00709/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id00709/00206_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id00909/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id00909/00037_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id00919/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id00919/00063_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id00946/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id00946/00126_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id00963/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id00963/00028_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id00981/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id00981/00092_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id00990/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id00990/00160_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id00999/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id00999/00028_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id01051/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id01051/00322_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id01052/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id01052/00076_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id01058/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id01058/00005_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id01098/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id01098/00044_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id01099/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id01099/00206_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id01102/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id01102/00197_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id01123/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id01123/00072_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id01126/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id01126/00040_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id01154/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id01154/00118_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id01156/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id01156/00078_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id01157/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id01157/00048_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id02567/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id02567/00040_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/men/id03205/
#   inflating: FakeAVCeleb_v1.2small/Fake/men/id03205/00150_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/
#    creating: FakeAVCeleb_v1.2small/Fake/women/id00042/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id00042/00028_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id00068/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id00068/00004_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id00071/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id00071/00014_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id00188/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id00188/00020_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id00232/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id00232/00025_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id00234/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id00234/00063_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id00262/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id00262/00028_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id00270/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id00270/00088_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id00271/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id00271/00028_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id00287/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id00287/00005_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id00325/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id00325/00015_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id00328/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id00328/00092_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id00330/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id00330/00118_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id00332/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id00332/00293_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id00365/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id00365/00078_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id00373/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id00373/00028_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id00374/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id00374/00311_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id00379/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id00379/00043_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id00395/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id00395/00420_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id00403/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id00403/00052_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id00434/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id00434/00046_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id00484/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id00484/00202_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id00491/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id00491/00122_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id00495/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id00495/00027_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id00496/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id00496/00015_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id00569/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id00569/00239_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id00581/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id00581/00010_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id00589/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id00589/00130_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id00591/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id00591/00001_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id00633/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id00633/00088_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id00634/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id00634/00078_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id00735/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id00735/00037_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id00806/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id00806/00005_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id00813/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id00813/00169_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id00823/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id00823/00125_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id00826/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id00826/00065_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id00897/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id00897/00005_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id01001/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id01001/00086_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id01002/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id01002/00043_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id01018/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id01018/00072_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id03371/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id03371/00430_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id03589/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id03589/00002_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id03620/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id03620/00081_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id03649/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id03649/00001_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id03651/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id03651/00092_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id03716/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id03716/00040_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id03816/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id03816/00093_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id03844/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id03844/00028_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id03858/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id03858/00092_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Fake/women/id03941/
#   inflating: FakeAVCeleb_v1.2small/Fake/women/id03941/00021_fake.mp3
#    creating: FakeAVCeleb_v1.2small/Real/
#    creating: FakeAVCeleb_v1.2small/Real/men/
#    creating: FakeAVCeleb_v1.2small/Real/men/id00055/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id00055/00120.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id00063/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id00063/00021.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id00171/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id00171/00092.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id00183/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id00183/00015.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id00185/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id00185/00015.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id00186/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id00186/00120.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id00187/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id00187/00360.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id00192/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id00192/00078.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id00225/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id00225/00078.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id00241/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id00241/00015.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id00253/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id00253/00021.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id00265/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id00265/00130.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id00266/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id00266/00470.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id00282/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id00282/00268.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id00292/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id00292/00072.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id00305/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id00305/00113.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id00306/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id00306/00015.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id00358/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id00358/00217.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id00368/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id00368/00078.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id00415/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id00415/00017.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id00498/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id00498/00014.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id00519/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id00519/00028.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id00520/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id00520/00187.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id00535/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id00535/00005.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id00548/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id00548/00015.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id00554/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id00554/00028.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id00559/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id00559/00078.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id00594/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id00594/00005.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id00694/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id00694/00340.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id00709/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id00709/00206.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id00909/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id00909/00037.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id00919/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id00919/00063.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id00946/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id00946/00126.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id00963/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id00963/00028.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id00981/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id00981/00092.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id00990/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id00990/00160.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id00999/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id00999/00028.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id01051/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id01051/00322.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id01052/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id01052/00076.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id01058/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id01058/00005.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id01098/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id01098/00044.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id01099/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id01099/00206.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id01102/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id01102/00197.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id01123/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id01123/00072.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id01126/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id01126/00040.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id01154/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id01154/00118.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id01156/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id01156/00078.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id01157/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id01157/00048.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id02567/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id02567/00040.mp3
#    creating: FakeAVCeleb_v1.2small/Real/men/id03205/
#   inflating: FakeAVCeleb_v1.2small/Real/men/id03205/00150.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/
#    creating: FakeAVCeleb_v1.2small/Real/women/id00042/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id00042/00028.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id00068/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id00068/00004.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id00071/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id00071/00014.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id00188/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id00188/00020.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id00232/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id00232/00025.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id00234/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id00234/00063.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id00262/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id00262/00028.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id00270/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id00270/00088.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id00271/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id00271/00028.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id00287/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id00287/00005.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id00325/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id00325/00015.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id00328/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id00328/00092.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id00330/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id00330/00118.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id00332/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id00332/00293.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id00365/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id00365/00078.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id00373/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id00373/00028.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id00374/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id00374/00311.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id00379/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id00379/00043.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id00395/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id00395/00420.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id00403/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id00403/00052.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id00434/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id00434/00046.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id00484/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id00484/00202.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id00491/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id00491/00122.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id00495/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id00495/00027.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id00496/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id00496/00015.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id00569/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id00569/00239.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id00581/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id00581/00010.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id00589/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id00589/00130.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id00591/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id00591/00001.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id00633/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id00633/00088.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id00634/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id00634/00078.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id00735/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id00735/00037.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id00806/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id00806/00005.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id00813/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id00813/00169.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id00823/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id00823/00125.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id00826/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id00826/00065.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id00897/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id00897/00005.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id01001/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id01001/00086.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id01002/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id01002/00043.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id01018/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id01018/00072.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id03371/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id03371/00430.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id03589/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id03589/00002.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id03620/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id03620/00081.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id03649/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id03649/00001.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id03651/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id03651/00092.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id03716/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id03716/00040.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id03816/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id03816/00093.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id03844/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id03844/00028.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id03858/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id03858/00092.mp3
#    creating: FakeAVCeleb_v1.2small/Real/women/id03941/
#   inflating: FakeAVCeleb_v1.2small/Real/women/id03941/00021.mp3

# %% [markdown]
# ##Importazione pacchetti

# %%
# Audio e Media
from pydub import AudioSegment # Per caricare, tagliare e salvare file audio
from IPython.display import Audio # Per riprodurre audio direttamente in notebook
import moviepy.editor as mp # Per elaborare file video

# Elaborazione audio
import librosa # Libreria principale per analisi del segnale audio
import librosa.display # Per visualizzare waveform e spettrogrammi
import numpy as np # Per operazioni matematiche e array numerici
import matplotlib.pyplot as plt # Per creare grafici statici

# Sistema operativo e gestione file
import os # Per navigare e gestire cartelle/file
import glob # Per trovare file con pattern
import shutil # Per spostare o copiare file


import random # Per generare numeri casuali

# Machine Learning
import sklearn
from sklearn.svm import SVC # Support Vector Machine per classificazione
from sklearn.pipeline import make_pipeline # Per creare pipeline ML con preprocessing + modello
from sklearn.preprocessing import StandardScaler # Normalizzazione standard (media=0, std=1)
from sklearn.model_selection import (
    train_test_split, # Dividisione dei dati in train/test
    StratifiedKFold, # k-fold mantenendo bilanciamento classi
    cross_val_score, # Valutazione modelli via cross-validation
    GridSearchCV # Cerca i migliori iperparametri con CV
    )

# Metriche di valutazione
from sklearn.metrics import (
    classification_report, # Riassunto con precision, recall, f1
    accuracy_score, # Percentuale di classificazioni corrette
    f1_score, # Media armonica tra precision e recall
    roc_curve, auc, # Per ROC curve e AUC
    confusion_matrix, # Matrice di confusione
    ConfusionMatrixDisplay, # Visualizzazione della matrice di confusione
    roc_auc_score # Calcola l'AUC per classificazione binaria
)


import seaborn as sns # Libreria grafica avanzata

# !pip install plotly
import plotly.graph_objects as go # Grafici


from tqdm import tqdm  # Barra di avanzamento
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/moviepy/video/io/sliders.py:61: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if event.key is 'enter':
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly) (8.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly) (25.0)

# %% [markdown]
# ##Prova funzionamento audio

# %% [markdown]
# Esempio audio real

# %%
audio_real_00028 ="/content/FakeAVCeleb_v1.2small/Real/men/id00963/00028.mp3"
Audio(audio_real_00028)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Esempio audio fake

# %%
audio_fake_00028  ="/content/FakeAVCeleb_v1.2small/Fake/men/id00963/00028_fake.mp3"
Audio(audio_fake_00028 )
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ##Conteggio dei campioni del dataset

# %%
def conta_file_audio(percorso_cartella, estensione=".mp3"):
    conta = 0
    for root, dirs, files in os.walk(percorso_cartella):
        for file in files:
            if file.lower().endswith(estensione):
                conta += 1
    return conta

# Percorso del dataset
dataset_path = "/content/FakeAVCeleb_v1.2small"

# Percorsi per ogni categoria
categorie = {
    "Real_men": os.path.join(dataset_path, "Real", "men"),
    "Real_women": os.path.join(dataset_path, "Real", "women"),
    "Fake_men": os.path.join(dataset_path, "Fake", "men"),
    "Fake_women": os.path.join(dataset_path, "Fake", "women"),
}

# Conta file
conteggi = {nome: conta_file_audio(path) for nome, path in categorie.items()}

# Calcolo dei totali
totale_real = conteggi["Real_men"] + conteggi["Real_women"]
totale_fake = conteggi["Fake_men"] + conteggi["Fake_women"]
totale_audio = totale_real + totale_fake

# Stampa
print(f"Numero totale di audio nel dataset: {totale_audio}\n")
print(f"Numero totale di audio REAL: {totale_real}\n")
print(f"Numero totale di audio FAKE: {totale_fake}\n")


# Estrai conteggi separati
real_men = conteggi["Real_men"]
real_women = conteggi["Real_women"]
fake_men = conteggi["Fake_men"]
fake_women = conteggi["Fake_women"]

# Prepara i dati per la bar chart impilata
labels = ["REAL", "FAKE"]
men_counts = [real_men, fake_men]
women_counts = [real_women, fake_women]

# Grafico a barre impilate
plt.figure(figsize=(8, 5))
# REAL: men (blue) + women (red)
plt.bar("REAL", real_men, label="Real - Men", color="blue")
plt.bar("REAL", real_women, bottom=real_men, label="Real - Women", color="red")

# FAKE
plt.bar("FAKE", fake_men, label="Fake - Men", color="lightblue")
plt.bar("FAKE", fake_women, bottom=fake_men, label="Fake - Women", color="lightcoral")

# Titolo e etichette
plt.title("Distribuzione audio REAL vs FAKE (Men vs Women)")
plt.ylabel("Numero di file audio")

# Legenda spostata a destra
plt.legend(loc="center left", bbox_to_anchor=(1.0, 0.5))
plt.tight_layout()
plt.show()
# Out:
# Numero totale di audio nel dataset: 200
#
# Numero totale di audio REAL: 100
#
# Numero totale di audio FAKE: 100

# %% [markdown]
# ##Salvataggio waveform

# %% [markdown]
# Salviamo le waveform di ogni audio nella sottocartella "waveform_originali"

# %%
# Percorsi base
root_audio = "/content/FakeAVCeleb_v1.2small"
save_waveform = "/content/waveform_originali"
os.makedirs(save_waveform, exist_ok=True)

def salva_waveform_originali(file_path):
    try:
        y, _ = librosa.load(file_path, sr=16000)
        base_name = os.path.splitext(os.path.basename(file_path))[0]

        # Percorso relativo al root originale
        rel_path = os.path.relpath(file_path, root_audio)
        rel_dir = os.path.dirname(rel_path)

        # Crea le sottocartelle nella destinazione
        dest_dir = os.path.join(save_waveform, rel_dir)
        os.makedirs(dest_dir, exist_ok=True)

        # Plot waveform
        plt.figure(figsize=(10, 3))
        librosa.display.waveshow(y, sr=16000)
        plt.title(f"Waveform - {base_name}")
        plt.xlabel("Tempo (s)")
        plt.ylabel("Ampiezza")
        plt.tight_layout()

        # Salvataggio in .png
        save_path = os.path.join(dest_dir, f"{base_name}_waveform.png")
        plt.savefig(save_path)
        plt.close()

    except Exception as e:
        print(f"❌ Errore su {file_path}: {e}")

# Ricerca degli mp3
all_wav_files = glob.glob(os.path.join(root_audio, "**", "*.mp3"), recursive=True)
print(f"Totale file trovati: {len(all_wav_files)}")

# Barra di progresso
for file_path in tqdm(all_wav_files, desc="Salvataggio waveform", unit="file"):
    salva_waveform_originali(file_path)
# Out:
# Totale file trovati: 200
# Salvataggio waveform: 100%|██████████| 200/200 [02:00<00:00,  1.67file/s]

# %% [markdown]
# #🎧 MEL

# %% [markdown]
# Uno spettrogramma MEL è una rappresentazione visiva del suono che mostra il cambiamento dell’energia delle frequenze nel tempo mappata sulla scala Mel, che imita la percezione umana delle frequenze. Questa scala Mel permette di comprimere le alte frequenze e di espandere le basse, in base a come l’orecchio umano distingue i suoni.
#
# - Partendo da un segnale audio, si applica la STFT (Short-Time Fourier Transform)che suddivide il suono in finestre e calcola lo spettro per ciascuna.
# - Successivamente vengono convertite le frequenze lineari in bande sulla scala Mel
# - Per migliorare la visibilità, si converte in scala logaritmica (dB).
#
#
# È una versione "umanamente percepibile" dello spettrogramma classico.

# %% [markdown]
# ##Esempio spettrogramma MEL su un audio

# %% [markdown]
# Visualizziamo come compare il contenuto spettrale di un audio fake e di un audio real con MEL

# %%
# File audio fake
audio_path_fake = "/content/FakeAVCeleb_v1.2small/Fake/men/id00963/00028_fake.mp3"

# Parametri
frame_length = 2048
hop_length = 512

sr=16000
n_mels = 128

y, sr = librosa.load(audio_path_fake, sr=sr)

mel_spectrogram = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=frame_length, hop_length=hop_length, n_mels=n_mels)

# Converto a decibel
mel_spectrogram_db = librosa.power_to_db(mel_spectrogram, ref=np.max)

# Visualizza MEL con asse x in secondi
plt.figure(figsize=(10, 3))
librosa.display.specshow(mel_spectrogram_db, sr=sr, x_axis='time', hop_length=hop_length,cmap='viridis')
plt.colorbar()
plt.title('MEL Audio 00028 Fake')
plt.xlabel("Tempo")
plt.ylabel("Frequenza Mel (scala log)")
plt.tight_layout()
plt.show()

#----------------------------
# File audio real
audio_path_real ="/content/FakeAVCeleb_v1.2small/Real/men/id00963/00028.mp3"
y, sr = librosa.load(audio_path_real, sr=sr)

mel_spectrogram = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=n_mels, hop_length=hop_length,n_fft=frame_length)

mel_spectrogram_db = librosa.power_to_db(mel_spectrogram, ref=np.max) #Conversione logaritmica


# Visualizza Mel con asse x in secondi
plt.figure(figsize=(10, 3))
librosa.display.specshow(mel_spectrogram_db, sr=sr, x_axis='time', hop_length=hop_length,cmap='viridis')
plt.colorbar()
plt.title('MEL Audio 00028 Real')
plt.xlabel("Tempo")
plt.ylabel("Frequenza Mel (scala log)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##Rimozione silenzi anomali con la feature Energy

# %% [markdown]
# ***Problema***: dallo studio del dataset, abbiamo potuto notare che la maggior parte degli audio fake presentano un silenzio finale. Questo è un problema perché c'è il rischio che il nostro modello impari a classificare gli audio solo grazie a questa pausa finale, il che sarebbe sbagliato.
#
# ***Soluzione***: utilizziamo la feature Energy per rilevare il silenzio, il rumore e il parlato. I silenzi e le pause sono importanti per distinguere gli audio real da quelli fake, e proprio per questo motivo eliminiamo solamente il silenzio presente sul finale dell'audio per evitare che il modello impari da questa caratteristica errata. Dopo aver eliminato il silenzio finale, in certi casi rimangono dei residui, sia all'inizio che alla fine dell'audio. Per evitare che il modello possa imparare da questi micro-pattern (anche se sono molto piccoli), effettuiamo un ulteriore taglio applicando una soglia più alta esclusivamente sulla testa e sulla coda dell'audio.
#
# In particolare, utilizziamo la RMS (Root Mean Square energy).

# %% [markdown]
# Esempio del taglio della pausa finale di un audio, che poi verrà eseguito su tutto il dataset:

# %%
# Carica audio
audio_path = "/content/FakeAVCeleb_v1.2small/Fake/men/id00963/00028_fake.mp3"
#audio_path = "/content/FakeAVCeleb_v1.2small/Fake/men/id00185/00015_fake.mp3"

# Parametri
frame_length = 2048
hop_length = 512
sr=16000
threshold=1e-3


y, sr = librosa.load(audio_path, sr=sr)


# Calcola energia RMS
rms = librosa.feature.rms(y=y, frame_length=frame_length, hop_length=hop_length)[0]
times = librosa.frames_to_time(np.arange(len(rms)), sr=sr, hop_length=hop_length)

threshold = 1e-3
non_silent = np.where(rms > threshold)[0]

def trim_silence(y, frame_length=frame_length, hop_length=hop_length, threshold=threshold):
    rms = librosa.feature.rms(y=y, frame_length=frame_length, hop_length=hop_length)[0]
    non_silent = np.where(rms > threshold)[0]

    if len(non_silent) > 0:
        last_frame = max(0, non_silent[-1])
        last_sample = librosa.frames_to_samples(last_frame + 1, hop_length=hop_length)
        y_trimmed = y[:last_sample]
        return y_trimmed, last_sample
    else:
        return np.array([]), 0


y_trimmed, last_sample = trim_silence(y)


#Tagliamo i residui di silenzio finale
def trim_energy_tail(y, sr, window_sec=0.03, energy_thresh=0.005):
    window_size = int(sr * window_sec)  # quanti campioni guardare (es. ultimi 0.1s)
    if len(y) < window_size:
        return y  # troppo corto per tagliare

    tail = y[-window_size:]  # prendi solo la coda finale
    energy = np.mean(tail ** 2)  # calcola l'energia della coda

    if energy < energy_thresh:  # se è davvero bassa
        return y[:-window_size]  # taglia via la coda
    return y

#Tagliamo i residui di silenzio iniziale
def trim_energy_head(y, sr, window_sec=0.03, energy_thresh=0.005):
    window_size = int(sr * window_sec)

    if len(y) < window_size:
        return y, 0

    head = y[:window_size]
    energy = np.mean(head ** 2)

    if energy < energy_thresh:
        return y[window_size:], window_size  # ritorna anche l'indice
    return y, 0



y_taglio_coda=trim_energy_tail(y_trimmed, sr)


# Applichiamo il trim iniziale e ottieniamo il numero di campioni tagliati
y_totale, start_sample = trim_energy_head(y_taglio_coda, sr=sr)

# Calcolo del tempo del taglio iniziale in secondi
cut_time_start = librosa.samples_to_time(start_sample, sr=sr)

# Calcolo del tempo del taglio finale (già lo fai)
cut_time_end = librosa.samples_to_time(last_sample, sr=sr)

# Calcolo per la visualizzazione
times = librosa.frames_to_time(np.arange(len(rms)), sr=sr, hop_length=hop_length)

# Trova il tempo del taglio finale (in secondi)
cut_time = librosa.samples_to_time(last_sample, sr=sr)

# Visualizzazione
plt.figure(figsize=(11, 6))

# Audio originale semplice
plt.subplot(3, 1, 1)
librosa.display.waveshow(y, sr=sr)
plt.title("Audio originale id00963/00028_fake")

# Audio originale con curva RMS
plt.subplot(3, 1, 2)
librosa.display.waveshow(y, sr=sr, alpha=0.6, label="Waveform")
plt.plot(times, rms, color='red', label="Energy (RMS)")
plt.axhline(y=threshold, color='r', linestyle='--', label="Threshold")
plt.axvline(x=cut_time, color='orange', linestyle='--', label="Taglio finale")
plt.axvline(x=cut_time_start, color='green', linestyle='--', label="Taglio Iniziale")
plt.title("Audio originale con curve dell'energia RMS")
plt.legend(loc="upper right")

# Audio dopo rimozione silenzio iniziale e finale
plt.subplot(3, 1, 3)
librosa.display.waveshow(y_totale, sr=sr)
plt.title("Dopo rimozione silenzio iniziale e finale")

plt.tight_layout()
plt.show()

# %% [markdown]
# ##Definizione dei parametri

# %%
'''
Sampling rate: è la frequenza di campionamento del segnale
audio, cioè quante volte al secondo viene campionato il
segnale analogico per convertirlo in digitale.
(range consigliato: 8000-22050 HZ)
'''
SR = 16000 # @param {type:"integer"}


'''
Controlla quante bande MEL (cioè quanti punti sull'asse delle frequenze) si vogliono generare.
Più alto è il valore di n_mels, più dettagliata sarà la rappresentazione spettrale
'''
N_MELS = 128 # @param {type:"integer"}


'''
L'hop length definisce quanto ci si sposta avanti nel segnale
da un frame al successivo.
'''
HOP_LENGTH=512 # @param {type:"integer"}


'''
Frame length definisce la dimensione della finestra di analisi.
Avere un frame_length maggiore dell'hop_length, ci permette di
avere più informazioni grazie alla sovrapposizione
'''
FRAME_LENGTH=2048 # @param {type:"integer"}

'''
Valore di soglia per togliere il silenzio finale
'''
THRESHOLD=1e-3 # @param {type:"number"}

'''
Finestra da guardare per analizzare i residui
'''
WINDOW_SEC = 0.03 # @param {type:"number"}

'''
Soglia per cancellare i residui (leggermente più grande della THRESHOLD)
'''
ENERGY_THRESH= 0.005 # @param {type:"number"}

# %% [markdown]
# ##Preprocessing dell'audio

# %% [markdown]
# Questa funzione si occupa della pre-elaborazione di un segnale audio per renderlo più omogeneo e privo di informazioni ridondanti prima dell'estrazione delle feature.
#
# 1. ***Caricamento del file audio***:
# inizialmente carichiamo il segnale audio utilizzando librosa.load(), con un campionamento forzato alla frequenza specificata (sr). Il file viene convertito in un array di campioni mono.
#
# 2. ***Rimozione del silenzio finale***:
# calcoliamo l’energia RMS (Root Mean Square) del segnale per identificare le porzioni silenziose. Se esistono frame con energia superiore a una soglia (threshold), viene individuato l’ultimo frame non silenzioso e il segnale viene troncato di conseguenza, eliminando il silenzio finale. In caso contrario, il file viene scartato perché considerato interamente silenzioso. Dopo che effettuiamo questo taglio, eliminiamo anche i residui con energy molto bassa che rimangono sulla testa e sulla coda dell'audio.
#
# 3. ***Normalizzazione del volume***:
# il segnale viene poi normalizzato per avere valori di volume compresi tra [-1, 1].
# Portiamo tutti gli audio allo stesso livello di riferimento, evitando che alcune clip influenzino il modello solo perché sono più forti o più deboli.
# In questo modo, riduciamo la variabilità dovuta al livello di registrazione anziché al contenuto fonetico o spettrale e riduciamo eventuali distorsioni.
#
#
# 4. ***Restituzione del segnale preprocessato***:
# il segnale audio risultante, ora normalizzato e privato di eventuale silenzio finale, viene restituito per essere successivamente utilizzato per l’estrazione di feature con MEL.

# %%
def preprocessing_audio(file_path, sr=SR, frame_length=FRAME_LENGTH, hop_length=HOP_LENGTH, threshold=THRESHOLD):

    # 1 - Caricamento audio
    y, _ = librosa.load(file_path, sr=sr)

    # Funzione che taglia il silenzio finale
    def trim_silence(y, frame_length=FRAME_LENGTH, hop_length=HOP_LENGTH, threshold=THRESHOLD):
        rms = librosa.feature.rms(y=y, frame_length=frame_length, hop_length=hop_length)[0]
        non_silent = np.where(rms > threshold)[0]

        if len(non_silent) > 0:
            last_frame = max(0, non_silent[-1])
            last_sample = librosa.frames_to_samples(last_frame + 1, hop_length=hop_length)
            y_trimmed = y[:last_sample]
            return y_trimmed, last_sample
        else:
            return np.array([]), 0

    # Funzione che taglia i residui dopo il taglio del silenzio finale
    def trim_energy_tail(y, sr, window_sec=WINDOW_SEC, energy_thresh=ENERGY_THRESH):
        window_size = int(sr * window_sec)
        if len(y) < window_size:
            return y
        tail = y[-window_size:]
        energy = np.mean(tail ** 2)
        if energy < energy_thresh:
            return y[:-window_size]
        return y

    # Funzione che taglia i residui iniziali
    def trim_energy_head(y, sr, window_sec=WINDOW_SEC, energy_thresh=ENERGY_THRESH):
        window_size = int(sr * window_sec)
        if len(y) < window_size:
            return y, 0
        head = y[:window_size]
        energy = np.mean(head ** 2)
        if energy < energy_thresh:
            return y[window_size:], window_size
        return y, 0

    # 2 - Rimozione silenzio finale tramite RMS
    y_trimmed, last_sample = trim_silence(y, frame_length=frame_length, hop_length=hop_length, threshold=threshold)
    if len(y_trimmed) == 0:
        raise ValueError(f"{file_path}: Audio interamente silenzioso.")

    # 3 - Rimozione residui silenzio finale tramite energia
    y_tail_trimmed = trim_energy_tail(y_trimmed, sr)

    # 4 - Rimozione residui silenzio iniziale tramite energia
    y_totale, start_sample = trim_energy_head(y_tail_trimmed, sr)

    # 5 - Normalizzazione volume
    if np.max(np.abs(y_totale)) > 0:
        y_totale = y_totale / np.max(np.abs(y_totale))
    else:
        raise ValueError(f"{file_path}: Segnale vuoto o completamente silenzioso dopo il trimming.")

    return y_totale

# %% [markdown]
# ##Estrazione delle features con MEL

# %% [markdown]
# Questa funzione serve per estrarre caratteristiche numeriche (feature) da un file audio, che saranno poi utilizzate per l’addestramento e la valutazione del classificatore.
#
# Trasformiamo un file .mp3 in un vettore numerico che rappresenta la sua firma acustica.

# %% [markdown]
# Per l'estrazione delle feature utilizziamo la media + deviazione standard per ogni set di features.
#
# 1. ***Media***: indica il valore medio di ogni coefficiente lungo tutto l’audio.
# Cattura il profilo acustico globale, come il timbro medio del segnale.
#
# 2. ***Deviazione standard***: misura quanto varia nel tempo ogni coefficiente, catturando la dinamica del parlato o delle transizioni nel suono.
#
# Usando sia media che std, combiniamo informazione di contenuto + dinamica.
#
# Applichiamo media e deviazione standard non solo sullo spettrogramma MEL ma anche sulle derivate temporali dei MEL:
#
# - Delta: misura la variazione tra un frame e i suoi vicini catturando la velocità del cambiamento acustico.
# - Delta-Delta: misura l’accelerazione del cambiamento fornendo un'indicazione della curvatura nel segnale vocale. Aggiunge ulteriore profondità per distinguere sfumature nel parlato.

# %%
def extract_features(file_path, sr=SR, n_mels=N_MELS, frame_length=FRAME_LENGTH, hop_length=HOP_LENGTH, threshold=THRESHOLD):
    y = preprocessing_audio(file_path, sr, frame_length, hop_length, threshold) # Carichiamo l'audio normalizzato
    # -------------------------------
    # ESTRAZIONE FEATURE MEL
    mels = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=n_mels, hop_length=hop_length,n_fft=FRAME_LENGTH) #Estrazione dei MEL
    mels_db = librosa.power_to_db(mels, ref=np.max)
    delta = librosa.feature.delta(mels_db) #Rappresenta la variazione nel tempo dei MEL (derivata prima).
    delta2 = librosa.feature.delta(mels_db, order=2) #Rappresenta la variazione della variazione (derivata seconda).

    #Calcoliamo la media e la deviazione standard per ogni set di feature
    features = np.concatenate([
        np.mean(mels_db, axis=1),
        np.mean(delta, axis=1),
        np.mean(delta2, axis=1),
        np.std(mels_db, axis=1),
        np.std(delta, axis=1),
        np.std(delta2, axis=1)
    ])
    #print(features)
    return features #Vettore numerico fisso

# %% [markdown]
# ##Caricamento del dataset

# %% [markdown]
# Carichiamo il dataset audio, estraiamo le feature da ciascun file .wav e associamo ad ognuno l'etichetta corretta.

# %%
def load_dataset(root_dir):
    X = []
    y = []
    file_paths = []  # Nuovo: per tracciare i nomi dei file

    for label_name in ["Real", "Fake"]:
        label = 0 if label_name == "Real" else 1
        for gender in ["men", "women"]:
            path = os.path.join(root_dir, label_name, gender)
            for speaker_id in os.listdir(path):
                speaker_path = os.path.join(path, speaker_id)
                for filename in os.listdir(speaker_path):
                    if filename.endswith(".mp3"):
                        file_path = os.path.join(speaker_path, filename)
                        try:
                            feats = extract_features(file_path)
                            X.append(feats)
                            y.append(label)
                            file_paths.append(file_path)  # Salviamo il nome del file
                        except Exception as e:
                            print(f"Errore con {file_path}: {e}")
    #print(X)
    return np.array(X), np.array(y), np.array(file_paths)

# %%
X, y, file_names  = load_dataset("/content/FakeAVCeleb_v1.2small")

# %% [markdown]
# #📊 Modello shallow SVM

# %% [markdown]
# *(Esempio di separazione con kernel non lineare)*

# %% [markdown]
# ![K_non_lineare.png](data:image/png;base64,...)

# %% [markdown]
# L’SVM è un classificatore supervisionato che cerca di trovare il miglior confine (iperpiano) che separa le due classi nei dati
#
# L’SVM cerca un iperpiano nello spazio delle feature (768 dimensioni nel nostro esempio) che separi al meglio le classi “Real” da quelle “Fake” utilizzando un kernel non lineare (rbf). Utilizziamo questo tipo di kernel perché gli audio sono elementi complessi, spesso non linearmente separabili.
#
# ***Perché 768?***
#
# Calcoliamo le statistiche "media e sd" per MEL, delta e delta^2, utilizzando 128 bande mel per ogni frame (768=128*6).
#
# Massimizza la distanza tra le due classi nel loro spazio MEL, cercando di trovare il confine più “robusto”.
#
# Non vede l’audio, ma solo il vettore numerico e la qualità della classificazione dipende da quanto bene le statistiche delo spettrogramma MEL riescono a catturare le differenze tra classi.
#
# Il modello definisce una frontiera nel feature space, basata sui valori medi e deviazioni del MEL

# %% [markdown]
# ##SVM: cross validation

# %% [markdown]
# ---
#
#
# Suddividiamo il dataset in 80% training set e 20% test set, in modo stratificato e riproducibile.
#
# stratify=y: garantisce che la proporzione di classi (Real/Fake) rimanga bilanciata sia nel train che nel test.

# %%
set_seed=10
# Dividiamo il dataset in train (80%) e test (20%)
X_train, X_test, y_train, y_test, files_train, files_test = train_test_split(
    X, y,file_names, test_size=0.2, stratify=y, random_state=set_seed
)

# %% [markdown]
# ---
#
#
# Ora costruiamo una pipeline che esegue due operazioni in sequenza:
# standardizzazione delle feature e addestramento del modello SVM con kernel RBF.
#
# * StandardScaler(): normalizza le feature centrandole (media = 0) e scalandole (sd = 1).
# È fondamentale per SVM, poiché il modello è sensibile alla scala delle feature e garantisce che tutte le dimensioni abbiano peso comparabile.
#
# * SVC(kernel='rbf', probability=True): utilizziamo un Support Vector Classifier con kernel='rbf', ovvero usa un kernel radiale (Radial Basis Function) che permette al modello di apprendere confini non lineari tra le classi.
# probability=True serve per abilitare la stima delle probabilità di appartenenza alle classi.

# %%
# Pipeline base (StandardScaler + SVC con RBF)
model = make_pipeline(StandardScaler(), SVC(kernel='rbf', probability=True))

# %% [markdown]
# ---
#
# StratifiedKFold mantiene le proporzioni originali tra le classi (Real e Fake) in ogni fold, utile in problemi di classificazione bilanciata/sbilanciata.
#
# La cross validation suddivide il training set in 5 fold e funziona così:
# 1. Il training set viene suddiviso in 5 parti (fold) di dimensioni simili.
#
# 2. Il modello viene allenato 5 volte: ogni volta su 4 fold (80%) e testato sul fold rimanente (20%, validation set).
#
# 3. Ogni fold fa da "valida" una sola volta.
#
# 4. Si calcola l’accuratezza media sui 5 round.
#
# 5. Questo processo viene applicato effettivamente all'interno di GridSearchCV e si ripete per ogni combinazione di C e gamma, valutando ogni combinazione di C e gamma usando accuracy come metrica (tuning degli iperparametri).
#
#
#
# ***A cosa servono gli iperparametri C e gamma?***
# * C: regola il compromesso tra accuratezza sul training e generalizzazione. Controlla quanta tolleranza all'errore ha il modello.
#
# * gamma: regola la "curvatura" della funzione decisionale (quanto è influenzata dai singoli punti).

# %% [markdown]
# Cambiando il seed, può succedere che le suddivisioni cambiano leggermente: diverse istanze finiscono in training o validation.
#
# Questo influenza la stima della performance di ogni combinazione di iperparametri, perciò potremo ritrovarci a volte delle stime di c e gamma diverse in training con seed differenti.
#
# ***Questo cambiamento è dovuto anche alla grandezza ridotta del nostro dataset***.

# %%
#Utilizzare skf permette di avere degli split bilanciati
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=set_seed)

# Griglia dei valori di C da testare
param_grid = {'svc__C': [0.001, 0.01, 0.1, 1, 10],
              'svc__gamma': [0.001, 0.01, 0.1,1, 10]}

# GridSearch con cross-validation 5-fold
grid = GridSearchCV(
    model,
    param_grid,
    cv=skf,
    scoring='accuracy',
    n_jobs=1,  # usa tutti i core -1
    refit=True,
    verbose=True
)

# Esegui grid search sul training set (80%)
grid.fit(X_train, y_train)

# Stampa i risultati
# Ricordiamo che c dipende da gamma e viceversa! Troviamo la combinazione migliore tra i valori
print("Miglior valore del parametro C:", grid.best_params_['svc__C'])
print("Miglior valore del parametro gamma:", grid.best_params_['svc__gamma'])
print("Accuracy media CV migliore:", grid.best_score_)

print(grid.best_estimator_)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# Miglior valore del parametro C: 10
# Miglior valore del parametro gamma: 0.001
# Accuracy media CV migliore: 0.9625
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('svc', SVC(C=10, gamma=0.001, probability=True))])

# %% [markdown]
# Prendiamo il modello ottimizzato con i migliori iperparametri trovati dalla GridSearchCV e effettuiamo la valutazione su test set.
#
# In grid abbiamo refit=True, perciò non abbiamo bisogno di ri-fittare il nostro modello finale

# %%
final_model = grid.best_estimator_

# Valutazione su test set
y_test_pred = final_model.predict(X_test) # predice le classi sugli esempi del test set, cioè quelli mai visti durante il training.
y_test_proba = final_model.predict_proba(X_test)[:, 1] # predice la probabilità della classe positiva

test_accuracy = accuracy_score(y_test, y_test_pred)

# %% [markdown]
# ##SVM: metriche e plot dei risultati

# %%
#------ Classification Report
print("Classification Report:")
print(classification_report(y_test, y_test_pred, target_names=["Real", "Fake"]))
print("\n\n")


#------ Riassunto metriche
print("Final test accuracy:", test_accuracy)


#------ Bar Plot dell'accuratezza
plt.figure(figsize=(3, 4))
plt.bar(["Accuracy"], [test_accuracy], color='green')
plt.ylim(0, 1)
plt.title(f"Accuracy: {test_accuracy*100:.2f}%")
plt.ylabel("Accuracy")
plt.grid(axis='y')
plt.tight_layout()
plt.show()
print("\n\n")


#------ Matrice di confusione
print("Matrice di confusione:")
cm = confusion_matrix(y_test, y_test_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Real", "Fake"])
disp.plot(cmap=plt.cm.Blues)
plt.title("Matrice di Confusione")
plt.grid(False)
plt.tight_layout()
plt.show()
print("\n\n")

#------ Curva ROC + AUC
r_auc = roc_auc_score(y_test, y_test_proba)
print("Test ROC AUC:", r_auc)

fpr, tpr, thresholds = roc_curve(y_test, y_test_proba)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6, 6))
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.2f}", color='darkorange', lw=2)
plt.plot([0, 1], [0, 1], linestyle='--', color='navy')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Curva ROC")
plt.legend(loc="lower right")
plt.grid()
plt.tight_layout()
plt.show()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#         Real       1.00      0.95      0.97        20
#         Fake       0.95      1.00      0.98        20
#
#     accuracy                           0.97        40
#    macro avg       0.98      0.97      0.97        40
# weighted avg       0.98      0.97      0.97        40
#
#
#
#
# Final test accuracy: 0.975
# Matrice di confusione:
# Test ROC AUC: 0.985

# %% [markdown]
# ##SVM: visualizzazione delle classificazioni errate

# %% [markdown]
# Visualizziamo quali audio sono stati classificati in modo errato.

# %%
# Lista degli errori
errors = [
    files_test[i] for i in range(len(y_test))
    if y_test[i] != y_test_pred[i]
]

# Stampa i nomi dei file con classificazione errata
print("Audio classificati erroneamente:")
for file_path in errors:
    print(file_path)
# Out:
# Audio classificati erroneamente:
# /content/FakeAVCeleb_v1.2small/Real/men/id00535/00005.mp3

# %% [markdown]
# Visualizziamo una galleria di 12 immagini di test (forma d’onda) dove è presente almeno un errore, indicando l'etichetta vera e le
# etichette predette da entrambi i classificatori. Le forma d'onda in questione sono degli audio non ancora trasformati e normalizzati.

# %%
# Percorso base da rimuovere nel titolo
base_path = "/content/FakeAVCeleb_v1.2small"

# Trova classificazioni errate e corrette
errors = []
corrects = []

for i in range(len(y_test)):
    if y_test[i] != y_test_pred[i]:
        errors.append((files_test[i], y_test[i], y_test_pred[i]))
    else:
        corrects.append((files_test[i], y_test[i], y_test_pred[i]))

# Numero di immagini da visualizzare
N_PLOTS = 12

# Selezioniamo tutte quelle errate e poi completiamo con alcune corrette
selected = errors[:N_PLOTS]  # massimo N_PLOTS errori
n_remaining = N_PLOTS - len(selected)

if n_remaining > 0:
    selected += corrects[:n_remaining]

# Plot
for file_path, true, pred in selected:

    y_audio, sr = librosa.load(file_path, sr=SR)

    # Plot forma d’onda
    plt.figure(figsize=(10, 2))
    librosa.display.waveshow(y_audio, sr=sr)

    # Percorso relativo (senza /content/FakeAVCeleb_v1.2small)
    relative_path = os.path.relpath(file_path, base_path)

    # Titolo con colore
    title_color = 'red' if true != pred else 'black'
    title = f"{relative_path} — Vero: {'Real' if true == 0 else 'Fake'} | Predetto: {'Real' if pred == 0 else 'Fake'}"
    plt.title(title, color=title_color)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# Ora visualizziamo sempre le 12 immagini di test che però rappresentano le forme d'onda dopo aver subito il preprocessing

# %%
# Percorso base da rimuovere nel titolo
base_path = "/content/FakeAVCeleb_v1.2small"

# Trova classificazioni errate e corrette
errors = []
corrects = []

for i in range(len(y_test)):
    if y_test[i] != y_test_pred[i]:
        errors.append((files_test[i], y_test[i], y_test_pred[i]))
    else:
        corrects.append((files_test[i], y_test[i], y_test_pred[i]))

# Numero di immagini da visualizzare
N_PLOTS = 12

# Selezioniamo tutte quelle errate e poi completiamo con alcune corrette
selected = errors[:N_PLOTS]  # massimo N_PLOTS errori
n_remaining = N_PLOTS - len(selected)

if n_remaining > 0:
    selected += corrects[:n_remaining]

# Plot
for file_path, true, pred in selected:
    y_audio = preprocessing_audio(file_path, SR, FRAME_LENGTH, HOP_LENGTH, THRESHOLD)
    #y_audio, sr = librosa.load(file_path, sr=SR)

    # Plot forma d’onda
    plt.figure(figsize=(10, 2))
    librosa.display.waveshow(y_audio, sr=sr)

    # Percorso relativo (senza /content/FakeAVCeleb_v1.2small)
    relative_path = os.path.relpath(file_path, base_path)

    # Titolo con colore
    title_color = 'red' if true != pred else 'black'
    title = f"{relative_path} — Vero: {'Real' if true == 0 else 'Fake'} | Predetto: {'Real' if pred == 0 else 'Fake'}"
    plt.title(title, color=title_color)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# #🎯 CONCLUSIONE: pro e contro dell'SVM utilizzando gli spettrogrammi MEL

# %% [markdown]
# ✅ PRO
#
# Come per l'SVM + MFCC:
#
# - E' abbastanza efficace con feature complesse e non lineari grazie anche all'utilizzo del kernel RBF.
#
# - Funziona bene e ha una buona capacità di generalizzazione con pochi dati
#
# - E' abbastanza veloce nel fare previsioni
#
# - I risultati in linea generale sono molti simili
#
# Rispetto all'SVM + MFCC:
#
# - Gli spettrogrammi Mel risultano più interpretabili e leggibili visivamente, poiché rappresentano direttamente l’evoluzione spettrale dell’audio nel tempo, mantenendo una struttura temporale e frequenziale chiara. Al contrario degli MFCC, il Mel Spectrogram conserva la relazione diretta tra frequenza (in scala Mel) e tempo, rendendolo molto più adatto a un’analisi visiva e strutturale del segnale. Dopo il preprocessing, con lo spettrogramma MEL è più facile capire i cambiamenti che sono avvenuti, mentre con MFCC risulta quasi impossibile capirlo, e per farlo dobbiamo per forza appoggiarci ad altre visualizzazioni (come la forma d'onda).

# %% [markdown]
# ❌ Contro
#
# Come per l'SVM + MFCC:
#
# - E' sensibile alla scelta dei parametri (C, gamma), perciò è necessario il tuning perché parametri sbilanciati possono causare overfitting o underfitting.
#
# - Risultati e robustezza dipendono fortemente dalla qualità delle feature estratte e dai parametri utilizzati per la creazione dello spettrogramma MEL (come il numero delle bande MEL prese in considerazione)
#
# - Viene notevolmente influenzato dal valore di soglia per la rimozione del silenzio finale: un valore troppo elevato rischia di tagliare parti importanti del parlato, mentre un valore troppo basso rischia di non tagliare abbastanza silenzio, compromettendo la classificazione e imparando i pattern di silenzio finale presenti principalmente nei fake.
#
# - In base al seed che utilizziamo, possiamo avere dei casi "sfavorevoli" in cui abbiamo un'accuratezza leggermente inferiore, sempre dovuti alla dimensione ridotta del nostro dataset
#
#
# A differenza dell'SVM + MFCC:
#
# - Trattandosi di uno spettrogramma non compresso, lo spettrogramma Mel presenta un’elevata dimensionalità, che comporta un maggiore costo computazionale.
# Nel nostro caso, avendo una dimensione ridotta del dataset, questo non rappresenta un problema concreto. Tuttavia, in scenari con dataset più ampi o modelli più leggeri, questa complessità dello spettrogramma Mel potrebbe diventare un fattore limitante.
# Proprio per questi motivi, a parità di prestazioni, nei modelli shallow è spesso più efficiente e saggio utilizzare gli MFCC, che offrono una rappresentazione più compatta.

# %% [markdown]
# ##Salvataggio audio trasformati

# %% [markdown]
# Salviamo le waveform e gli spettrogrammi MEL post-normalizzazione per visualizzare le modifiche effettuate

# %%
#Solo se serve
def reset_directory(dir_path):
    # Se la cartella esiste, la rimuove completamente
    if os.path.exists(dir_path):
        shutil.rmtree(dir_path)

    # Ricrea la cartella vuota
    os.makedirs(dir_path)

reset_directory("/content/waveform_trasformati")
reset_directory("/content/MEL_trasformati")

# %%
# Cartelle di salvataggio
save_waveform_dir = "/content/waveform_trasformati"
output_mel_dir = "/content/MEL_trasformati"
os.makedirs(save_waveform_dir, exist_ok=True)
os.makedirs(output_mel_dir, exist_ok=True)

# %%
# Directory principali
root_audio = "/content/FakeAVCeleb_v1.2small"


# Funzione per salvare immagini
def salva_spettrogrammi(file_path):
    try:
        y = preprocessing_audio(file_path, SR, FRAME_LENGTH, HOP_LENGTH, THRESHOLD)
        base_name = os.path.splitext(os.path.basename(file_path))[0]

        # Percorso relativo rispetto alla root
        rel_path = os.path.relpath(file_path, root_audio)
        rel_dir = os.path.dirname(rel_path)

        # Percorsi di salvataggio (con stessa struttura)
        waveform_subdir = os.path.join(save_waveform_dir, rel_dir)
        mel_subdir = os.path.join(output_mel_dir, rel_dir)

        os.makedirs(waveform_subdir, exist_ok=True)
        os.makedirs(mel_subdir, exist_ok=True)

        # --- Waveform ---
        plt.figure(figsize=(10, 3))
        librosa.display.waveshow(y, sr=SR)
        plt.title(f"Waveform - {base_name}")
        plt.xlabel("Tempo (s)")
        plt.ylabel("Ampiezza")
        plt.tight_layout()
        plt.savefig(os.path.join(waveform_subdir, f"{base_name}_waveform.png"))
        plt.close()

        # --- MEL ---
        mel_spectrogram = librosa.feature.melspectrogram(y=y, sr=SR, n_fft=FRAME_LENGTH, hop_length=HOP_LENGTH, n_mels=N_MELS)
        mels_db = librosa.power_to_db(mel_spectrogram, ref=np.max)  # Conversione logaritmica
        plt.figure(figsize=(10, 4))
        librosa.display.specshow(mels_db, sr=SR, x_axis='time', hop_length=HOP_LENGTH, cmap='viridis')
        plt.colorbar()
        plt.title('MEL')
        plt.tight_layout()
        plt.savefig(os.path.join(mel_subdir, f"{base_name}_mel.png"))
        plt.close()

    except Exception as e:
        print(f"❌ Errore su {file_path}: {e}")

# Trova tutti i .mp3
all_files = glob.glob(os.path.join(root_audio, "**", "*.mp3"), recursive=True)
print(f"Totale file trovati: {len(all_files)}")

# Esegui conversione con barra di progresso
for file_path in tqdm(all_files, desc="Salvataggio waveform + MEL", unit="file"):
    salva_spettrogrammi(file_path)
# Out:
# Totale file trovati: 200
# Salvataggio waveform + MEL: 100%|██████████| 200/200 [02:37<00:00,  1.27file/s]
